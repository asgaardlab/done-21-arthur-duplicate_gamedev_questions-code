# %%
from create_tables import *
pd.set_option('display.max_rows', 500)

# %%
dataset_sizes()
# Out:
# All datasets have std == 0
#                                    Questions Non-duplicates    Duplicates  \
# Source         Topic
# Stack Exchange Game development       51,797         50,694  1,103 (2.1%)
# Stack Overflow Game development       68,200         67,191  1,009 (1.5%)
#                General development    59,998         58,891  1,107 (1.8%)
#
#                                     Pairs
# Source         Topic
# Stack Exchange Game development     1,144
# Stack Overflow Game development     1,070
#                General development  1,107

# %%
dup_pair_similarity_summary()
# Out:
#                                                                     (1)  \
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard             15.41
#                                              TF-IDF              18.04
#                                              BM25                16.95
#                                              Topic                0.00
#                                              Doc2Vec              0.00
#                                              BERTOverflow         5.26
#                                              MPNet               27.20
#                               recall-rate@10 Jaccard             20.13
#                                              TF-IDF              21.94
#                                              BM25                22.21
#                                              Topic                0.54
# ...

# %%
candidate_evaluation_summary()
# Out:
#                                           Recall-rate@                \
#                                                      5            10
# dataset                       candidates
# Game Dev. Stack Exchange      100               39.37         46.15
#                               250               38.01         47.51
#                               500               36.20         44.80
#                               750               38.01         49.77
#                               1000              38.46         46.15
#                               1500              40.27         50.68
#                               2000              39.82         47.51
#                               2500              41.18         49.32
#                               5000              40.72         50.23
#                               7500              38.91         49.32
#                               10000             38.46         47.96
# ...

# %%
print(cross_dataset_summary().to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
#                               &                               & \multicolumn{3}{l}{Recall-rate@} \\
#                               &                               &             5 &            10 &            20 \\
# dataset\_train & dataset\_test &               &               &               \\
# \midrule
# Game Dev. Stack Exchange & Game Dev. Stack Exchange &        40.27  &        50.68  &        58.82  \\
# Stack Overflow (Game dev.) & Game Dev. Stack Exchange &        35.75  &        44.80  &        53.39  \\
# Stack Overflow (General dev.) & Game Dev. Stack Exchange &  39.00 (2.03) &  48.60 (1.30) &  55.84 (0.41) \\
# Game Dev. Stack Exchange & Stack Overflow (Game dev.) &        26.73  &        35.15  &        47.03  \\
# Stack Overflow (Game dev.) & Stack Overflow (Game dev.) &        27.23  &        38.12  &        50.00  \\
# Stack Overflow (General dev.) & Stack Overflow (Game dev.) &  25.54 (0.57) &  33.27 (0.81) &  45.05 (1.68) \\
# ...

# %%
misclassified_summary()
# Out:
#                                       Description Game Dev. Stack Exchange  \
# 0                     Duplicate pairs in test set                      221
# 1                   Misclassified duplicate pairs                91 (100%)
# 2     Main question not in the list of candidates                 19 (21%)
# 3  Top ranked question is an unlabelled duplicate                 44 (48%)
# 4    Main question discusses a more general topic                 40 (44%)
#
#   Stack Overflow (Game dev.) Stack Overflow (General dev.)
# 0                        202                           221
# 1                 101 (100%)                     53 (100%)
# 2                   19 (19%)                      13 (25%)
# 3                   51 (50%)                      10 (19%)
# 4                   42 (42%)                      28 (53%)
